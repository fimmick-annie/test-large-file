# %% [markdown]
# # 转换并量化中文LLaMA-2和Alpaca-2模型
#
# 项目地址：https://github.com/ymcui/Chinese-LLaMA-Alpaca-2
#
# ⚠️ 内存消耗提示（确保刷出来的机器RAM大于以下要求）：
# - 7B模型：15G+
# - 13B模型：18G+
# - 33B模型：22G+
#
# 💡 提示和小窍门：
# - 免费用户默认的内存只有12G左右，不足以转换模型。**实测选择TPU的话有机会随机出35G内存**，建议多试几次
# - Pro(+)用户请选择 “代码执行程序” -> “更改运行时类型” -> “高RAM”
# - 程序莫名崩掉或断开连接就说明内存爆了
# - 如果选了“高RAM”之后内存还是不够大的话，选择以下操作，有的时候会分配出很高内存的机器，祝你好运😄！
#     - 可以把GPU或者TPU也选上（虽然不会用到）
#     - 选GPU时，Pro(+)用户可选“A100”类型GPU
#
# *温馨提示：用完之后注意断开运行时，选择满足要求的最低配置即可，避免不必要的计算单元消耗（Pro只给100个计算单元）。*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 安装相关依赖

# %%
# !pip install git+https://github.com/huggingface/peft.git@13e53fc
# !pip install transformers==4.31.0
# !pip install sentencepiece==0.1.97
# !pip install bitsandbytes==0.39.1
# Out:
# Collecting git+https://github.com/huggingface/peft.git@13e53fc
#   Cloning https://github.com/huggingface/peft.git (to revision 13e53fc) to /tmp/pip-req-build-hspk3le2
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-hspk3le2
#   WARNING: Did not find branch or tag '13e53fc', assuming revision or ref.
#   Running command git checkout -q 13e53fc
#   Resolved https://github.com/huggingface/peft.git to commit 13e53fc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft==0.3.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.3.0.dev0) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft==0.3.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft==0.3.0.dev0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.3.0.dev0) (2.0.1+cu118)
# Collecting transformers (from peft==0.3.0.dev0)
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 29.2 MB/s eta 0:00:00
# Collecting accelerate (from peft==0.3.0.dev0)
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft==0.3.0.dev0) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft==0.3.0.dev0) (16.0.6)
# Collecting huggingface-hub (from accelerate->peft==0.3.0.dev0)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 32.1 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.3.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.3.0.dev0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->peft==0.3.0.dev0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 84.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->peft==0.3.0.dev0)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.3.0.dev0) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate->peft==0.3.0.dev0) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft==0.3.0.dev0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.3.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.3.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.3.0.dev0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.3.0.dev0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft==0.3.0.dev0) (1.3.0)
# Building wheels for collected packages: peft
#   Building wheel for peft (pyproject.toml) ... done
#   Created wheel for peft: filename=peft-0.3.0.dev0-py3-none-any.whl size=40646 sha256=2a647f544ff04136bb1d2193c40b9c247727773a3de297e6619d2d2a4267ddb7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cp1xbtnh/wheels/d9/13/c6/404d5f8a81c5620f65f7fd75b6a66619f013cd79c2875b981c
# Successfully built peft
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers, accelerate, peft
# Successfully installed accelerate-0.23.0 huggingface-hub-0.17.2 peft-0.3.0.dev0 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2
# Collecting transformers==4.31.0
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 27.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.17.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2023.7.22)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.33.2
#     Uninstalling transformers-4.33.2:
#       Successfully uninstalled transformers-4.33.2
# Successfully installed transformers-4.31.0
# Collecting sentencepiece==0.1.97
#   Downloading sentencepiece-0.1.97-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.9 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Collecting bitsandbytes==0.39.1
#   Downloading bitsandbytes-0.39.1-py3-none-any.whl (97.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 16.8 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.39.1

# %% [markdown]
# ## 克隆目录和代码

# %%
# !git clone https://github.com/ggerganov/llama.cpp
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 9225, done.
# remote: Counting objects: 100% (3620/3620), done.
# remote: Compressing objects: 100% (456/456), done.
# remote: Total 9225 (delta 3375), reused 3294 (delta 3164), pack-reused 5605
# Receiving objects: 100% (9225/9225), 8.41 MiB | 25.18 MiB/s, done.
# Resolving deltas: 100% (6362/6362), done.

# %% [markdown]
# ## 合并模型（以LLaMA-2-7B为例）
#
# 合并LoRA，生成全量模型权重。可以直接指定🤗模型库的地址，也可以是本地存放地址。
# - 基模型：`meta-llama/Llama-2-7b-hf`（注意需要官方授权）
#     - 这里使用一个平替（SHA256一致）做演示：`daryl149/llama-2-7b-hf`
# - LoRA模型：`ziqingyang/chinese-llama-2-lora-7b`
# - 输出格式：可选pth或者huggingface，这里选择huggingface
#
# 转换好的模型存放在`llama-2-7b-combined`目录。
# 如果你不需要量化模型，那么到这一步就结束了，可自行下载或者转存到Google Drive。

# %%
# !python /content/drive/MyDrive/Llama2_ch/scripts/merge_llama2_with_chinese_lora_low_mem.py \
    --base_model /content/drive/MyDrive/Llama2_ch/models \
    --lora_model /content/drive/MyDrive/Llama2_ch/output/sft_lora_model \
    --output_type huggingface \
    --output_dir /content/drive/MyDrive/Llama2_ch/combine_models
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so: undefined symbol: cadam32bit_grad_fp32
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so...
# ================================================================================
# Base model: /content/drive/MyDrive/Llama2_ch/models
# LoRA model: /content/drive/MyDrive/Llama2_ch/output/sft_lora_model
# Loading /content/drive/MyDrive/Llama2_ch/output/sft_lora_model
# You are using the legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This means that tokens that come after special tokens will not be properly handled. We recommend you to read the related pull request available at https://github.com/huggingface/transformers/pull/24565
# Loading ckpt pytorch_model-00001-of-00003.bin
# Merging...
# Saving ckpt pytorch_model-00001-of-00003.bin to /content/drive/MyDrive/Llama2_ch/combine_models in HF format...
# Loading ckpt pytorch_model-00002-of-00003.bin
# Merging...
# Saving ckpt pytorch_model-00002-of-00003.bin to /content/drive/MyDrive/Llama2_ch/combine_models in HF format...
# Loading ckpt pytorch_model-00003-of-00003.bin
# Merging...
# Saving ckpt pytorch_model-00003-of-00003.bin to /content/drive/MyDrive/Llama2_ch/combine_models in HF format...
# Saving tokenizer
# Saving config.json from /content/drive/MyDrive/Llama2_ch/models
# Saving generation_config.json from /content/drive/MyDrive/Llama2_ch/models
# Saving pytorch_model.bin.index.json from /content/drive/MyDrive/Llama2_ch/models
# Done.
# Check output dir: /content/drive/MyDrive/Llama2_ch/combine_models

# %% [markdown]
# ## 检查修改config.json（如果使用meta原版则可跳过）
#
# - Llama-2的config中途有一次更新。因为本教程里使用的是第三方的权重，并没有及时更新对应的`config.json`文件。
#
# - 请手动打开`llama-2-7b-combined`文件夹下的config.json（可直接双击打开），将`max_position_embeddings`字段由`2048`改为`4096`。cmd/ctrl+s保存即可。

# %% [markdown]
# ## 量化模型
# 接下来我们使用[llama.cpp](https://github.com/ggerganov/llama.cpp)工具对上一步生成的全量版本权重进行转换，生成量化模型。
#
# ### 编译工具
#
# 首先对llama.cpp工具进行编译。

# %%
# !cd llama.cpp && make
# Out:
# I llama.cpp build info:
# I UNAME_S:  Linux
# I UNAME_P:  x86_64
# I UNAME_M:  x86_64
# I CFLAGS:   -I.            -O3 -std=c11   -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wdouble-promotion -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS
# I CXXFLAGS: -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS
# I LDFLAGS:
# I CC:       cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# I CXX:      g++ (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#
# cc  -I.            -O3 -std=c11   -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wdouble-promotion -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS   -c ggml.c -o ggml.o
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS -c llama.cpp -o llama.o
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS -c common/common.cpp -o common.o
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS -c common/console.cpp -o console.o
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS -c common/grammar-parser.cpp -o grammar-parser.o
# cc -I.            -O3 -std=c11   -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wdouble-promotion -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS   -c -o k_quants.o k_quants.c
# k_quants.c:182:14: warning: ‘make_qkx1_quants’ defined but not used [-Wunused-function]
#   182 | static float make_qkx1_quants(int n, int nmax, const float * restrict x, uint8_t * restrict L, float * restrict the_min,
#       |              ^~~~~~~~~~~~~~~~
# cc  -I.            -O3 -std=c11   -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wdouble-promotion -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS   -c ggml-alloc.c -o ggml-alloc.o
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/main/main.cpp ggml.o llama.o common.o console.o grammar-parser.o k_quants.o ggml-alloc.o -o main
#
# ====  Run ./main -h for help.  ====
#
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/quantize/quantize.cpp ggml.o llama.o k_quants.o ggml-alloc.o -o quantize
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/quantize-stats/quantize-stats.cpp ggml.o llama.o k_quants.o ggml-alloc.o -o quantize-stats
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/perplexity/perplexity.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o perplexity
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/embedding/embedding.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o embedding
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS pocs/vdot/vdot.cpp ggml.o k_quants.o ggml-alloc.o -o vdot
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/train-text-from-scratch/train-text-from-scratch.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o train-text-from-scratch
# examples/train-text-from-scratch/train-text-from-scratch.cpp: In function ‘ggml_tensor* llama_build_train_graphs(my_llama_model*, ggml_allocr*, ggml_context*, ggml_cgraph*, ggml_cgraph*, ggml_cgraph*, ggml_tensor**, ggml_tensor*, ggml_tensor*, int, int, bool, bool)’:
# examples/train-text-from-scratch/train-text-from-scratch.cpp:739:68: warning: ‘kv_scale’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   739 |             struct ggml_tensor * t16_1 = ggml_scale_inplace        (ctx, t16_0, kv_scale);          set_name(t16_1, "t16_1"); assert_shape_4d(t16_1, N, N, n_head, n_batch);
#       |                                          ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/convert-llama2c-to-ggml/convert-llama2c-to-ggml.cpp ggml.o llama.o k_quants.o ggml-alloc.o -o convert-llama2c-to-ggml
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/simple/simple.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o simple
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/save-load-state/save-load-state.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o save-load-state
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS -Iexamples/server examples/server/server.cpp ggml.o llama.o common.o grammar-parser.o k_quants.o ggml-alloc.o -o server
# g++ --shared -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/embd-input/embd-input-lib.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o libembdinput.so
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/embd-input/embd-input-test.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o embd-input-test  -L. -lembdinput
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/gguf/gguf.cpp ggml.o llama.o k_quants.o ggml-alloc.o -o gguf
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/llama-bench/llama-bench.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o llama-bench
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/baby-llama/baby-llama.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o baby-llama
# examples/baby-llama/baby-llama.cpp: In function ‘int main(int, char**)’:
# examples/baby-llama/baby-llama.cpp:1620:32: warning: variable ‘opt_params_adam’ set but not used [-Wunused-but-set-variable]
#  1620 |         struct ggml_opt_params opt_params_adam = ggml_opt_default_params(GGML_OPT_ADAM);
#       |                                ^~~~~~~~~~~~~~~
# g++ -I. -I./common -O3 -std=c++11 -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wno-multichar -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS examples/beam-search/beam-search.cpp ggml.o llama.o common.o k_quants.o ggml-alloc.o -o beam-search
# cc -I.            -O3 -std=c11   -fPIC -DNDEBUG -Wall -Wextra -Wpedantic -Wcast-qual -Wdouble-promotion -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -pthread -march=native -mtune=native -DGGML_USE_K_QUANTS -c tests/test-c.c -o tests/test-c.o

# %% [markdown]
# ### 模型转换为GGML格式（FP16）
#
# 这一步，我们将模型转换为GGML格式（FP16）。

# %%
# !pip install gguf
# Out:
# Collecting gguf
#   Downloading gguf-0.3.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from gguf) (1.23.5)
# Installing collected packages: gguf
# Successfully installed gguf-0.3.0

# %%
# !cd llama.cpp && python convert.py /content/drive/MyDrive/Llama2_ch/combine_models
# Out:
# Loading model file /content/drive/MyDrive/Llama2_ch/combine_models/pytorch_model-00001-of-00003.bin
# Loading model file /content/drive/MyDrive/Llama2_ch/combine_models/pytorch_model-00001-of-00003.bin
# Loading model file /content/drive/MyDrive/Llama2_ch/combine_models/pytorch_model-00002-of-00003.bin
# Loading model file /content/drive/MyDrive/Llama2_ch/combine_models/pytorch_model-00003-of-00003.bin
# params = Params(n_vocab=55296, n_embd=5120, n_mult=6912, n_layer=40, n_ctx=4096, n_ff=13824, n_head=40, n_head_kv=40, f_norm_eps=1e-05, f_rope_freq_base=None, f_rope_scale=None, ftype=None, path_model=PosixPath('/content/drive/MyDrive/Llama2_ch/combine_models'))
# Loading vocab file '/content/drive/MyDrive/Llama2_ch/combine_models/tokenizer.model', type 'spm'
# Permuting layer 0
# Permuting layer 1
# Permuting layer 2
# Permuting layer 3
# Permuting layer 4
# Permuting layer 5
# Permuting layer 6
# Permuting layer 7
# Permuting layer 8
# Permuting layer 9
# Permuting layer 10
# Permuting layer 11
# Permuting layer 12
# Permuting layer 13
# Permuting layer 14
# Permuting layer 15
# Permuting layer 16
# Permuting layer 17
# Permuting layer 18
# Permuting layer 19
# Permuting layer 20
# Permuting layer 21
# Permuting layer 22
# Permuting layer 23
# Permuting layer 24
# Permuting layer 25
# Permuting layer 26
# Permuting layer 27
# Permuting layer 28
# Permuting layer 29
# Permuting layer 30
# Permuting layer 31
# Permuting layer 32
# Permuting layer 33
# Permuting layer 34
# Permuting layer 35
# Permuting layer 36
# Permuting layer 37
# Permuting layer 38
# Permuting layer 39
# model.embed_tokens.weight                        -> token_embd.weight                        | F16    | [55296, 5120]
# model.layers.0.self_attn.q_proj.weight           -> blk.0.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.0.self_attn.k_proj.weight           -> blk.0.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.0.self_attn.v_proj.weight           -> blk.0.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.0.self_attn.o_proj.weight           -> blk.0.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.0.attn_rot_embd
# model.layers.0.mlp.gate_proj.weight              -> blk.0.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.0.mlp.up_proj.weight                -> blk.0.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.0.mlp.down_proj.weight              -> blk.0.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.0.input_layernorm.weight            -> blk.0.attn_norm.weight                   | F16    | [5120]
# model.layers.0.post_attention_layernorm.weight   -> blk.0.ffn_norm.weight                    | F16    | [5120]
# model.layers.1.self_attn.q_proj.weight           -> blk.1.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.1.self_attn.k_proj.weight           -> blk.1.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.1.self_attn.v_proj.weight           -> blk.1.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.1.self_attn.o_proj.weight           -> blk.1.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.1.attn_rot_embd
# model.layers.1.mlp.gate_proj.weight              -> blk.1.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.1.mlp.up_proj.weight                -> blk.1.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.1.mlp.down_proj.weight              -> blk.1.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.1.input_layernorm.weight            -> blk.1.attn_norm.weight                   | F16    | [5120]
# model.layers.1.post_attention_layernorm.weight   -> blk.1.ffn_norm.weight                    | F16    | [5120]
# model.layers.2.self_attn.q_proj.weight           -> blk.2.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.2.self_attn.k_proj.weight           -> blk.2.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.2.self_attn.v_proj.weight           -> blk.2.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.2.self_attn.o_proj.weight           -> blk.2.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.2.attn_rot_embd
# model.layers.2.mlp.gate_proj.weight              -> blk.2.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.2.mlp.up_proj.weight                -> blk.2.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.2.mlp.down_proj.weight              -> blk.2.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.2.input_layernorm.weight            -> blk.2.attn_norm.weight                   | F16    | [5120]
# model.layers.2.post_attention_layernorm.weight   -> blk.2.ffn_norm.weight                    | F16    | [5120]
# model.layers.3.self_attn.q_proj.weight           -> blk.3.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.3.self_attn.k_proj.weight           -> blk.3.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.3.self_attn.v_proj.weight           -> blk.3.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.3.self_attn.o_proj.weight           -> blk.3.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.3.attn_rot_embd
# model.layers.3.mlp.gate_proj.weight              -> blk.3.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.3.mlp.up_proj.weight                -> blk.3.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.3.mlp.down_proj.weight              -> blk.3.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.3.input_layernorm.weight            -> blk.3.attn_norm.weight                   | F16    | [5120]
# model.layers.3.post_attention_layernorm.weight   -> blk.3.ffn_norm.weight                    | F16    | [5120]
# model.layers.4.self_attn.q_proj.weight           -> blk.4.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.4.self_attn.k_proj.weight           -> blk.4.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.4.self_attn.v_proj.weight           -> blk.4.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.4.self_attn.o_proj.weight           -> blk.4.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.4.attn_rot_embd
# model.layers.4.mlp.gate_proj.weight              -> blk.4.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.4.mlp.up_proj.weight                -> blk.4.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.4.mlp.down_proj.weight              -> blk.4.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.4.input_layernorm.weight            -> blk.4.attn_norm.weight                   | F16    | [5120]
# model.layers.4.post_attention_layernorm.weight   -> blk.4.ffn_norm.weight                    | F16    | [5120]
# model.layers.5.self_attn.q_proj.weight           -> blk.5.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.5.self_attn.k_proj.weight           -> blk.5.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.5.self_attn.v_proj.weight           -> blk.5.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.5.self_attn.o_proj.weight           -> blk.5.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.5.attn_rot_embd
# model.layers.5.mlp.gate_proj.weight              -> blk.5.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.5.mlp.up_proj.weight                -> blk.5.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.5.mlp.down_proj.weight              -> blk.5.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.5.input_layernorm.weight            -> blk.5.attn_norm.weight                   | F16    | [5120]
# model.layers.5.post_attention_layernorm.weight   -> blk.5.ffn_norm.weight                    | F16    | [5120]
# model.layers.6.self_attn.q_proj.weight           -> blk.6.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.6.self_attn.k_proj.weight           -> blk.6.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.6.self_attn.v_proj.weight           -> blk.6.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.6.self_attn.o_proj.weight           -> blk.6.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.6.attn_rot_embd
# model.layers.6.mlp.gate_proj.weight              -> blk.6.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.6.mlp.up_proj.weight                -> blk.6.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.6.mlp.down_proj.weight              -> blk.6.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.6.input_layernorm.weight            -> blk.6.attn_norm.weight                   | F16    | [5120]
# model.layers.6.post_attention_layernorm.weight   -> blk.6.ffn_norm.weight                    | F16    | [5120]
# model.layers.7.self_attn.q_proj.weight           -> blk.7.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.7.self_attn.k_proj.weight           -> blk.7.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.7.self_attn.v_proj.weight           -> blk.7.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.7.self_attn.o_proj.weight           -> blk.7.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.7.attn_rot_embd
# model.layers.7.mlp.gate_proj.weight              -> blk.7.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.7.mlp.up_proj.weight                -> blk.7.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.7.mlp.down_proj.weight              -> blk.7.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.7.input_layernorm.weight            -> blk.7.attn_norm.weight                   | F16    | [5120]
# model.layers.7.post_attention_layernorm.weight   -> blk.7.ffn_norm.weight                    | F16    | [5120]
# model.layers.8.self_attn.q_proj.weight           -> blk.8.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.8.self_attn.k_proj.weight           -> blk.8.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.8.self_attn.v_proj.weight           -> blk.8.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.8.self_attn.o_proj.weight           -> blk.8.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.8.attn_rot_embd
# model.layers.8.mlp.gate_proj.weight              -> blk.8.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.8.mlp.up_proj.weight                -> blk.8.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.8.mlp.down_proj.weight              -> blk.8.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.8.input_layernorm.weight            -> blk.8.attn_norm.weight                   | F16    | [5120]
# model.layers.8.post_attention_layernorm.weight   -> blk.8.ffn_norm.weight                    | F16    | [5120]
# model.layers.9.self_attn.q_proj.weight           -> blk.9.attn_q.weight                      | F16    | [5120, 5120]
# model.layers.9.self_attn.k_proj.weight           -> blk.9.attn_k.weight                      | F16    | [5120, 5120]
# model.layers.9.self_attn.v_proj.weight           -> blk.9.attn_v.weight                      | F16    | [5120, 5120]
# model.layers.9.self_attn.o_proj.weight           -> blk.9.attn_output.weight                 | F16    | [5120, 5120]
# skipping tensor blk.9.attn_rot_embd
# model.layers.9.mlp.gate_proj.weight              -> blk.9.ffn_gate.weight                    | F16    | [13824, 5120]
# model.layers.9.mlp.up_proj.weight                -> blk.9.ffn_up.weight                      | F16    | [13824, 5120]
# model.layers.9.mlp.down_proj.weight              -> blk.9.ffn_down.weight                    | F16    | [5120, 13824]
# model.layers.9.input_layernorm.weight            -> blk.9.attn_norm.weight                   | F16    | [5120]
# model.layers.9.post_attention_layernorm.weight   -> blk.9.ffn_norm.weight                    | F16    | [5120]
# model.layers.10.self_attn.q_proj.weight          -> blk.10.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.10.self_attn.k_proj.weight          -> blk.10.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.10.self_attn.v_proj.weight          -> blk.10.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.10.self_attn.o_proj.weight          -> blk.10.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.10.attn_rot_embd
# model.layers.10.mlp.gate_proj.weight             -> blk.10.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.10.mlp.up_proj.weight               -> blk.10.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.10.mlp.down_proj.weight             -> blk.10.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.10.input_layernorm.weight           -> blk.10.attn_norm.weight                  | F16    | [5120]
# model.layers.10.post_attention_layernorm.weight  -> blk.10.ffn_norm.weight                   | F16    | [5120]
# model.layers.11.self_attn.q_proj.weight          -> blk.11.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.11.self_attn.k_proj.weight          -> blk.11.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.11.self_attn.v_proj.weight          -> blk.11.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.11.self_attn.o_proj.weight          -> blk.11.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.11.attn_rot_embd
# model.layers.11.mlp.gate_proj.weight             -> blk.11.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.11.mlp.up_proj.weight               -> blk.11.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.11.mlp.down_proj.weight             -> blk.11.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.11.input_layernorm.weight           -> blk.11.attn_norm.weight                  | F16    | [5120]
# model.layers.11.post_attention_layernorm.weight  -> blk.11.ffn_norm.weight                   | F16    | [5120]
# model.layers.12.self_attn.q_proj.weight          -> blk.12.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.12.self_attn.k_proj.weight          -> blk.12.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.12.self_attn.v_proj.weight          -> blk.12.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.12.self_attn.o_proj.weight          -> blk.12.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.12.attn_rot_embd
# model.layers.12.mlp.gate_proj.weight             -> blk.12.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.12.mlp.up_proj.weight               -> blk.12.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.12.mlp.down_proj.weight             -> blk.12.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.12.input_layernorm.weight           -> blk.12.attn_norm.weight                  | F16    | [5120]
# model.layers.12.post_attention_layernorm.weight  -> blk.12.ffn_norm.weight                   | F16    | [5120]
# model.layers.13.self_attn.q_proj.weight          -> blk.13.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.13.self_attn.k_proj.weight          -> blk.13.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.13.self_attn.v_proj.weight          -> blk.13.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.13.self_attn.o_proj.weight          -> blk.13.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.13.attn_rot_embd
# model.layers.13.mlp.gate_proj.weight             -> blk.13.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.13.mlp.up_proj.weight               -> blk.13.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.13.mlp.down_proj.weight             -> blk.13.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.13.input_layernorm.weight           -> blk.13.attn_norm.weight                  | F16    | [5120]
# model.layers.13.post_attention_layernorm.weight  -> blk.13.ffn_norm.weight                   | F16    | [5120]
# model.layers.14.self_attn.q_proj.weight          -> blk.14.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.14.self_attn.k_proj.weight          -> blk.14.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.14.self_attn.v_proj.weight          -> blk.14.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.14.self_attn.o_proj.weight          -> blk.14.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.14.attn_rot_embd
# model.layers.14.mlp.gate_proj.weight             -> blk.14.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.14.mlp.up_proj.weight               -> blk.14.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.14.mlp.down_proj.weight             -> blk.14.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.14.input_layernorm.weight           -> blk.14.attn_norm.weight                  | F16    | [5120]
# model.layers.14.post_attention_layernorm.weight  -> blk.14.ffn_norm.weight                   | F16    | [5120]
# model.layers.15.self_attn.q_proj.weight          -> blk.15.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.15.self_attn.k_proj.weight          -> blk.15.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.15.self_attn.v_proj.weight          -> blk.15.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.15.self_attn.o_proj.weight          -> blk.15.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.15.attn_rot_embd
# model.layers.15.mlp.gate_proj.weight             -> blk.15.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.15.mlp.up_proj.weight               -> blk.15.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.15.mlp.down_proj.weight             -> blk.15.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.15.input_layernorm.weight           -> blk.15.attn_norm.weight                  | F16    | [5120]
# model.layers.15.post_attention_layernorm.weight  -> blk.15.ffn_norm.weight                   | F16    | [5120]
# model.layers.16.self_attn.q_proj.weight          -> blk.16.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.16.self_attn.k_proj.weight          -> blk.16.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.16.self_attn.v_proj.weight          -> blk.16.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.16.self_attn.o_proj.weight          -> blk.16.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.16.attn_rot_embd
# model.layers.16.mlp.gate_proj.weight             -> blk.16.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.16.mlp.up_proj.weight               -> blk.16.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.16.mlp.down_proj.weight             -> blk.16.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.16.input_layernorm.weight           -> blk.16.attn_norm.weight                  | F16    | [5120]
# model.layers.16.post_attention_layernorm.weight  -> blk.16.ffn_norm.weight                   | F16    | [5120]
# model.layers.17.self_attn.q_proj.weight          -> blk.17.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.17.self_attn.k_proj.weight          -> blk.17.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.17.self_attn.v_proj.weight          -> blk.17.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.17.self_attn.o_proj.weight          -> blk.17.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.17.attn_rot_embd
# model.layers.17.mlp.gate_proj.weight             -> blk.17.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.17.mlp.up_proj.weight               -> blk.17.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.17.mlp.down_proj.weight             -> blk.17.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.17.input_layernorm.weight           -> blk.17.attn_norm.weight                  | F16    | [5120]
# model.layers.17.post_attention_layernorm.weight  -> blk.17.ffn_norm.weight                   | F16    | [5120]
# model.layers.18.self_attn.q_proj.weight          -> blk.18.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.18.self_attn.k_proj.weight          -> blk.18.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.18.self_attn.v_proj.weight          -> blk.18.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.18.self_attn.o_proj.weight          -> blk.18.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.18.attn_rot_embd
# model.layers.18.mlp.gate_proj.weight             -> blk.18.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.18.mlp.up_proj.weight               -> blk.18.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.18.mlp.down_proj.weight             -> blk.18.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.18.input_layernorm.weight           -> blk.18.attn_norm.weight                  | F16    | [5120]
# model.layers.18.post_attention_layernorm.weight  -> blk.18.ffn_norm.weight                   | F16    | [5120]
# model.layers.19.self_attn.q_proj.weight          -> blk.19.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.19.self_attn.k_proj.weight          -> blk.19.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.19.self_attn.v_proj.weight          -> blk.19.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.19.self_attn.o_proj.weight          -> blk.19.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.19.attn_rot_embd
# model.layers.19.mlp.gate_proj.weight             -> blk.19.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.19.mlp.up_proj.weight               -> blk.19.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.19.mlp.down_proj.weight             -> blk.19.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.19.input_layernorm.weight           -> blk.19.attn_norm.weight                  | F16    | [5120]
# model.layers.19.post_attention_layernorm.weight  -> blk.19.ffn_norm.weight                   | F16    | [5120]
# model.layers.20.self_attn.q_proj.weight          -> blk.20.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.20.self_attn.k_proj.weight          -> blk.20.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.20.self_attn.v_proj.weight          -> blk.20.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.20.self_attn.o_proj.weight          -> blk.20.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.20.attn_rot_embd
# model.layers.20.mlp.gate_proj.weight             -> blk.20.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.20.mlp.up_proj.weight               -> blk.20.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.20.mlp.down_proj.weight             -> blk.20.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.20.input_layernorm.weight           -> blk.20.attn_norm.weight                  | F16    | [5120]
# model.layers.20.post_attention_layernorm.weight  -> blk.20.ffn_norm.weight                   | F16    | [5120]
# model.layers.21.self_attn.q_proj.weight          -> blk.21.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.21.self_attn.k_proj.weight          -> blk.21.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.21.self_attn.v_proj.weight          -> blk.21.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.21.self_attn.o_proj.weight          -> blk.21.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.21.attn_rot_embd
# model.layers.21.mlp.gate_proj.weight             -> blk.21.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.21.mlp.up_proj.weight               -> blk.21.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.21.mlp.down_proj.weight             -> blk.21.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.21.input_layernorm.weight           -> blk.21.attn_norm.weight                  | F16    | [5120]
# model.layers.21.post_attention_layernorm.weight  -> blk.21.ffn_norm.weight                   | F16    | [5120]
# model.layers.22.self_attn.q_proj.weight          -> blk.22.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.22.self_attn.k_proj.weight          -> blk.22.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.22.self_attn.v_proj.weight          -> blk.22.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.22.self_attn.o_proj.weight          -> blk.22.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.22.attn_rot_embd
# model.layers.22.mlp.gate_proj.weight             -> blk.22.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.22.mlp.up_proj.weight               -> blk.22.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.22.mlp.down_proj.weight             -> blk.22.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.22.input_layernorm.weight           -> blk.22.attn_norm.weight                  | F16    | [5120]
# model.layers.22.post_attention_layernorm.weight  -> blk.22.ffn_norm.weight                   | F16    | [5120]
# model.layers.23.self_attn.q_proj.weight          -> blk.23.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.23.self_attn.k_proj.weight          -> blk.23.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.23.self_attn.v_proj.weight          -> blk.23.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.23.self_attn.o_proj.weight          -> blk.23.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.23.attn_rot_embd
# model.layers.23.mlp.gate_proj.weight             -> blk.23.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.23.mlp.up_proj.weight               -> blk.23.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.23.mlp.down_proj.weight             -> blk.23.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.23.input_layernorm.weight           -> blk.23.attn_norm.weight                  | F16    | [5120]
# model.layers.23.post_attention_layernorm.weight  -> blk.23.ffn_norm.weight                   | F16    | [5120]
# model.layers.24.self_attn.q_proj.weight          -> blk.24.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.24.self_attn.k_proj.weight          -> blk.24.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.24.self_attn.v_proj.weight          -> blk.24.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.24.self_attn.o_proj.weight          -> blk.24.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.24.attn_rot_embd
# model.layers.24.mlp.gate_proj.weight             -> blk.24.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.24.mlp.up_proj.weight               -> blk.24.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.24.mlp.down_proj.weight             -> blk.24.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.24.input_layernorm.weight           -> blk.24.attn_norm.weight                  | F16    | [5120]
# model.layers.24.post_attention_layernorm.weight  -> blk.24.ffn_norm.weight                   | F16    | [5120]
# model.layers.25.self_attn.q_proj.weight          -> blk.25.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.25.self_attn.k_proj.weight          -> blk.25.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.25.self_attn.v_proj.weight          -> blk.25.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.25.self_attn.o_proj.weight          -> blk.25.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.25.attn_rot_embd
# model.layers.25.mlp.gate_proj.weight             -> blk.25.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.25.mlp.up_proj.weight               -> blk.25.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.25.mlp.down_proj.weight             -> blk.25.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.25.input_layernorm.weight           -> blk.25.attn_norm.weight                  | F16    | [5120]
# model.layers.25.post_attention_layernorm.weight  -> blk.25.ffn_norm.weight                   | F16    | [5120]
# model.layers.26.self_attn.q_proj.weight          -> blk.26.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.26.self_attn.k_proj.weight          -> blk.26.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.26.self_attn.v_proj.weight          -> blk.26.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.26.self_attn.o_proj.weight          -> blk.26.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.26.attn_rot_embd
# model.layers.26.mlp.gate_proj.weight             -> blk.26.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.26.mlp.up_proj.weight               -> blk.26.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.26.mlp.down_proj.weight             -> blk.26.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.26.input_layernorm.weight           -> blk.26.attn_norm.weight                  | F16    | [5120]
# model.layers.26.post_attention_layernorm.weight  -> blk.26.ffn_norm.weight                   | F16    | [5120]
# model.layers.27.self_attn.q_proj.weight          -> blk.27.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.27.self_attn.k_proj.weight          -> blk.27.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.27.self_attn.v_proj.weight          -> blk.27.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.27.self_attn.o_proj.weight          -> blk.27.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.27.attn_rot_embd
# model.layers.27.mlp.gate_proj.weight             -> blk.27.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.27.mlp.up_proj.weight               -> blk.27.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.27.mlp.down_proj.weight             -> blk.27.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.27.input_layernorm.weight           -> blk.27.attn_norm.weight                  | F16    | [5120]
# model.layers.27.post_attention_layernorm.weight  -> blk.27.ffn_norm.weight                   | F16    | [5120]
# model.layers.28.self_attn.q_proj.weight          -> blk.28.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.28.self_attn.k_proj.weight          -> blk.28.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.28.self_attn.v_proj.weight          -> blk.28.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.28.self_attn.o_proj.weight          -> blk.28.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.28.attn_rot_embd
# model.layers.28.mlp.gate_proj.weight             -> blk.28.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.28.mlp.up_proj.weight               -> blk.28.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.28.mlp.down_proj.weight             -> blk.28.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.28.input_layernorm.weight           -> blk.28.attn_norm.weight                  | F16    | [5120]
# model.layers.28.post_attention_layernorm.weight  -> blk.28.ffn_norm.weight                   | F16    | [5120]
# model.layers.29.self_attn.q_proj.weight          -> blk.29.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.29.self_attn.k_proj.weight          -> blk.29.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.29.self_attn.v_proj.weight          -> blk.29.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.29.self_attn.o_proj.weight          -> blk.29.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.29.attn_rot_embd
# model.layers.29.mlp.gate_proj.weight             -> blk.29.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.29.mlp.up_proj.weight               -> blk.29.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.29.mlp.down_proj.weight             -> blk.29.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.29.input_layernorm.weight           -> blk.29.attn_norm.weight                  | F16    | [5120]
# model.layers.29.post_attention_layernorm.weight  -> blk.29.ffn_norm.weight                   | F16    | [5120]
# model.layers.30.self_attn.q_proj.weight          -> blk.30.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.30.self_attn.k_proj.weight          -> blk.30.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.30.self_attn.v_proj.weight          -> blk.30.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.30.self_attn.o_proj.weight          -> blk.30.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.30.attn_rot_embd
# model.layers.30.mlp.gate_proj.weight             -> blk.30.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.30.mlp.up_proj.weight               -> blk.30.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.30.mlp.down_proj.weight             -> blk.30.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.30.input_layernorm.weight           -> blk.30.attn_norm.weight                  | F16    | [5120]
# model.layers.30.post_attention_layernorm.weight  -> blk.30.ffn_norm.weight                   | F16    | [5120]
# model.layers.31.self_attn.q_proj.weight          -> blk.31.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.31.self_attn.k_proj.weight          -> blk.31.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.31.self_attn.v_proj.weight          -> blk.31.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.31.self_attn.o_proj.weight          -> blk.31.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.31.attn_rot_embd
# model.layers.31.mlp.gate_proj.weight             -> blk.31.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.31.mlp.up_proj.weight               -> blk.31.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.31.mlp.down_proj.weight             -> blk.31.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.31.input_layernorm.weight           -> blk.31.attn_norm.weight                  | F16    | [5120]
# model.layers.31.post_attention_layernorm.weight  -> blk.31.ffn_norm.weight                   | F16    | [5120]
# model.layers.32.self_attn.q_proj.weight          -> blk.32.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.32.self_attn.k_proj.weight          -> blk.32.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.32.self_attn.v_proj.weight          -> blk.32.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.32.self_attn.o_proj.weight          -> blk.32.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.32.attn_rot_embd
# model.layers.32.mlp.gate_proj.weight             -> blk.32.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.32.mlp.up_proj.weight               -> blk.32.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.32.mlp.down_proj.weight             -> blk.32.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.32.input_layernorm.weight           -> blk.32.attn_norm.weight                  | F16    | [5120]
# model.layers.32.post_attention_layernorm.weight  -> blk.32.ffn_norm.weight                   | F16    | [5120]
# model.layers.33.self_attn.q_proj.weight          -> blk.33.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.33.self_attn.k_proj.weight          -> blk.33.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.33.self_attn.v_proj.weight          -> blk.33.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.33.self_attn.o_proj.weight          -> blk.33.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.33.attn_rot_embd
# model.layers.33.mlp.gate_proj.weight             -> blk.33.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.33.mlp.up_proj.weight               -> blk.33.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.33.mlp.down_proj.weight             -> blk.33.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.33.input_layernorm.weight           -> blk.33.attn_norm.weight                  | F16    | [5120]
# model.layers.33.post_attention_layernorm.weight  -> blk.33.ffn_norm.weight                   | F16    | [5120]
# model.layers.34.self_attn.q_proj.weight          -> blk.34.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.34.self_attn.k_proj.weight          -> blk.34.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.34.self_attn.v_proj.weight          -> blk.34.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.34.self_attn.o_proj.weight          -> blk.34.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.34.attn_rot_embd
# model.layers.34.mlp.gate_proj.weight             -> blk.34.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.34.mlp.up_proj.weight               -> blk.34.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.34.mlp.down_proj.weight             -> blk.34.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.34.input_layernorm.weight           -> blk.34.attn_norm.weight                  | F16    | [5120]
# model.layers.34.post_attention_layernorm.weight  -> blk.34.ffn_norm.weight                   | F16    | [5120]
# model.layers.35.self_attn.q_proj.weight          -> blk.35.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.35.self_attn.k_proj.weight          -> blk.35.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.35.self_attn.v_proj.weight          -> blk.35.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.35.self_attn.o_proj.weight          -> blk.35.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.35.attn_rot_embd
# model.layers.35.mlp.gate_proj.weight             -> blk.35.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.35.mlp.up_proj.weight               -> blk.35.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.35.mlp.down_proj.weight             -> blk.35.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.35.input_layernorm.weight           -> blk.35.attn_norm.weight                  | F16    | [5120]
# model.layers.35.post_attention_layernorm.weight  -> blk.35.ffn_norm.weight                   | F16    | [5120]
# model.layers.36.self_attn.q_proj.weight          -> blk.36.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.36.self_attn.k_proj.weight          -> blk.36.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.36.self_attn.v_proj.weight          -> blk.36.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.36.self_attn.o_proj.weight          -> blk.36.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.36.attn_rot_embd
# model.layers.36.mlp.gate_proj.weight             -> blk.36.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.36.mlp.up_proj.weight               -> blk.36.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.36.mlp.down_proj.weight             -> blk.36.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.36.input_layernorm.weight           -> blk.36.attn_norm.weight                  | F16    | [5120]
# model.layers.36.post_attention_layernorm.weight  -> blk.36.ffn_norm.weight                   | F16    | [5120]
# model.layers.37.self_attn.q_proj.weight          -> blk.37.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.37.self_attn.k_proj.weight          -> blk.37.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.37.self_attn.v_proj.weight          -> blk.37.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.37.self_attn.o_proj.weight          -> blk.37.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.37.attn_rot_embd
# model.layers.37.mlp.gate_proj.weight             -> blk.37.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.37.mlp.up_proj.weight               -> blk.37.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.37.mlp.down_proj.weight             -> blk.37.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.37.input_layernorm.weight           -> blk.37.attn_norm.weight                  | F16    | [5120]
# model.layers.37.post_attention_layernorm.weight  -> blk.37.ffn_norm.weight                   | F16    | [5120]
# model.layers.38.self_attn.q_proj.weight          -> blk.38.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.38.self_attn.k_proj.weight          -> blk.38.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.38.self_attn.v_proj.weight          -> blk.38.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.38.self_attn.o_proj.weight          -> blk.38.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.38.attn_rot_embd
# model.layers.38.mlp.gate_proj.weight             -> blk.38.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.38.mlp.up_proj.weight               -> blk.38.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.38.mlp.down_proj.weight             -> blk.38.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.38.input_layernorm.weight           -> blk.38.attn_norm.weight                  | F16    | [5120]
# model.layers.38.post_attention_layernorm.weight  -> blk.38.ffn_norm.weight                   | F16    | [5120]
# model.layers.39.self_attn.q_proj.weight          -> blk.39.attn_q.weight                     | F16    | [5120, 5120]
# model.layers.39.self_attn.k_proj.weight          -> blk.39.attn_k.weight                     | F16    | [5120, 5120]
# model.layers.39.self_attn.v_proj.weight          -> blk.39.attn_v.weight                     | F16    | [5120, 5120]
# model.layers.39.self_attn.o_proj.weight          -> blk.39.attn_output.weight                | F16    | [5120, 5120]
# skipping tensor blk.39.attn_rot_embd
# model.layers.39.mlp.gate_proj.weight             -> blk.39.ffn_gate.weight                   | F16    | [13824, 5120]
# model.layers.39.mlp.up_proj.weight               -> blk.39.ffn_up.weight                     | F16    | [13824, 5120]
# model.layers.39.mlp.down_proj.weight             -> blk.39.ffn_down.weight                   | F16    | [5120, 13824]
# model.layers.39.input_layernorm.weight           -> blk.39.attn_norm.weight                  | F16    | [5120]
# model.layers.39.post_attention_layernorm.weight  -> blk.39.ffn_norm.weight                   | F16    | [5120]
# model.norm.weight                                -> output_norm.weight                       | F16    | [5120]
# lm_head.weight                                   -> output.weight                            | F16    | [55296, 5120]
# Writing /content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-f16.gguf, format 1
# gguf: Setting special token type bos to 1
# gguf: Setting special token type eos to 2
# [  1/363] Writing tensor token_embd.weight                      | size  55296 x   5120  | type F16  | T+   3
# [  2/363] Writing tensor blk.0.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   4
# [  3/363] Writing tensor blk.0.attn_k.weight                    | size   5120 x   5120  | type F16  | T+   4
# [  4/363] Writing tensor blk.0.attn_v.weight                    | size   5120 x   5120  | type F16  | T+   4
# [  5/363] Writing tensor blk.0.attn_output.weight               | size   5120 x   5120  | type F16  | T+   4
# [  6/363] Writing tensor blk.0.ffn_gate.weight                  | size  13824 x   5120  | type F16  | T+   4
# [  7/363] Writing tensor blk.0.ffn_up.weight                    | size  13824 x   5120  | type F16  | T+   7
# [  8/363] Writing tensor blk.0.ffn_down.weight                  | size   5120 x  13824  | type F16  | T+   7
# [  9/363] Writing tensor blk.0.attn_norm.weight                 | size   5120           | type F32  | T+   7
# [ 10/363] Writing tensor blk.0.ffn_norm.weight                  | size   5120           | type F32  | T+   7
# [ 11/363] Writing tensor blk.1.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   7
# [ 12/363] Writing tensor blk.1.attn_k.weight                    | size   5120 x   5120  | type F16  | T+   7
# [ 13/363] Writing tensor blk.1.attn_v.weight                    | size   5120 x   5120  | type F16  | T+   8
# [ 14/363] Writing tensor blk.1.attn_output.weight               | size   5120 x   5120  | type F16  | T+   8
# [ 15/363] Writing tensor blk.1.ffn_gate.weight                  | size  13824 x   5120  | type F16  | T+   9
# [ 16/363] Writing tensor blk.1.ffn_up.weight                    | size  13824 x   5120  | type F16  | T+   9
# [ 17/363] Writing tensor blk.1.ffn_down.weight                  | size   5120 x  13824  | type F16  | T+  10
# [ 18/363] Writing tensor blk.1.attn_norm.weight                 | size   5120           | type F32  | T+  10
# [ 19/363] Writing tensor blk.1.ffn_norm.weight                  | size   5120           | type F32  | T+  10
# [ 20/363] Writing tensor blk.2.attn_q.weight                    | size   5120 x   5120  | type F16  | T+  10
# [ 21/363] Writing tensor blk.2.attn_k.weight                    | size   5120 x   5120  | type F16  | T+  10
# [ 22/363] Writing tensor blk.2.attn_v.weight                    | size   5120 x   5120  | type F16  | T+  11
# [ 23/363] Writing tensor blk.2.attn_output.weight               | size   5120 x   5120  | type F16  | T+  11
# [ 24/363] Writing tensor blk.2.ffn_gate.weight                  | size  13824 x   5120  | type F16  | T+  11
# [ 25/363] Writing tensor blk.2.ffn_up.weight                    | size  13824 x   5120  | type F16  | T+  12
# ...
# [218/363] Writing tensor blk.24.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  86
# [219/363] Writing tensor blk.24.attn_k.weight                   | size   5120 x   5120  | type F16  | T+  86
# [220/363] Writing tensor blk.24.attn_v.weight                   | size   5120 x   5120  | type F16  | T+  86
# [221/363] Writing tensor blk.24.attn_output.weight              | size   5120 x   5120  | type F16  | T+  86
# [222/363] Writing tensor blk.24.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+  87
# [223/363] Writing tensor blk.24.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+  87
# [224/363] Writing tensor blk.24.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+  89
# [225/363] Writing tensor blk.24.attn_norm.weight                | size   5120           | type F32  | T+  89
# [226/363] Writing tensor blk.24.ffn_norm.weight                 | size   5120           | type F32  | T+  89
# [227/363] Writing tensor blk.25.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  89
# [228/363] Writing tensor blk.25.attn_k.weight                   | size   5120 x   5120  | type F16  | T+  90
# [229/363] Writing tensor blk.25.attn_v.weight                   | size   5120 x   5120  | type F16  | T+  90
# [230/363] Writing tensor blk.25.attn_output.weight              | size   5120 x   5120  | type F16  | T+  90
# [231/363] Writing tensor blk.25.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+  90
# [232/363] Writing tensor blk.25.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+  92
# [233/363] Writing tensor blk.25.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+  93
# [234/363] Writing tensor blk.25.attn_norm.weight                | size   5120           | type F32  | T+  93
# [235/363] Writing tensor blk.25.ffn_norm.weight                 | size   5120           | type F32  | T+  93
# [236/363] Writing tensor blk.26.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  93
# [237/363] Writing tensor blk.26.attn_k.weight                   | size   5120 x   5120  | type F16  | T+  93
# [238/363] Writing tensor blk.26.attn_v.weight                   | size   5120 x   5120  | type F16  | T+  93
# [239/363] Writing tensor blk.26.attn_output.weight              | size   5120 x   5120  | type F16  | T+  94
# [240/363] Writing tensor blk.26.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+  94
# [241/363] Writing tensor blk.26.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+  95
# [242/363] Writing tensor blk.26.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+  96
# [243/363] Writing tensor blk.26.attn_norm.weight                | size   5120           | type F32  | T+  96
# [244/363] Writing tensor blk.26.ffn_norm.weight                 | size   5120           | type F32  | T+  96
# [245/363] Writing tensor blk.27.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  96
# [246/363] Writing tensor blk.27.attn_k.weight                   | size   5120 x   5120  | type F16  | T+  96
# [247/363] Writing tensor blk.27.attn_v.weight                   | size   5120 x   5120  | type F16  | T+  97
# [248/363] Writing tensor blk.27.attn_output.weight              | size   5120 x   5120  | type F16  | T+  97
# [249/363] Writing tensor blk.27.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+  97
# [250/363] Writing tensor blk.27.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+  99
# [251/363] Writing tensor blk.27.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+  99
# [252/363] Writing tensor blk.27.attn_norm.weight                | size   5120           | type F32  | T+  99
# [253/363] Writing tensor blk.27.ffn_norm.weight                 | size   5120           | type F32  | T+  99
# [254/363] Writing tensor blk.28.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  99
# [255/363] Writing tensor blk.28.attn_k.weight                   | size   5120 x   5120  | type F16  | T+  99
# [256/363] Writing tensor blk.28.attn_v.weight                   | size   5120 x   5120  | type F16  | T+  99
# [257/363] Writing tensor blk.28.attn_output.weight              | size   5120 x   5120  | type F16  | T+ 100
# [258/363] Writing tensor blk.28.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+ 101
# [259/363] Writing tensor blk.28.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+ 101
# [260/363] Writing tensor blk.28.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+ 103
# [261/363] Writing tensor blk.28.attn_norm.weight                | size   5120           | type F32  | T+ 103
# [262/363] Writing tensor blk.28.ffn_norm.weight                 | size   5120           | type F32  | T+ 103
# [263/363] Writing tensor blk.29.attn_q.weight                   | size   5120 x   5120  | type F16  | T+ 103
# [264/363] Writing tensor blk.29.attn_k.weight                   | size   5120 x   5120  | type F16  | T+ 103
# [265/363] Writing tensor blk.29.attn_v.weight                   | size   5120 x   5120  | type F16  | T+ 103
# [266/363] Writing tensor blk.29.attn_output.weight              | size   5120 x   5120  | type F16  | T+ 104
# [267/363] Writing tensor blk.29.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+ 104
# [268/363] Writing tensor blk.29.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+
attn_q.weight                   | size   5120 x   5120  | type F16  | T+ 126
# [327/363] Writing tensor blk.36.attn_k.weight                   | size   5120 x   5120  | type F16  | T+ 126
# [328/363] Writing tensor blk.36.attn_v.weight                   | size   5120 x   5120  | type F16  | T+ 126
# [329/363] Writing tensor blk.36.attn_output.weight              | size   5120 x   5120  | type F16  | T+ 126
# [330/363] Writing tensor blk.36.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+ 127
# [331/363] Writing tensor blk.36.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+ 129
# [332/363] Writing tensor blk.36.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+ 129
# [333/363] Writing tensor blk.36.attn_norm.weight                | size   5120           | type F32  | T+ 130
# [334/363] Writing tensor blk.36.ffn_norm.weight                 | size   5120           | type F32  | T+ 130
# [335/363] Writing tensor blk.37.attn_q.weight                   | size   5120 x   5120  | type F16  | T+ 130
# [336/363] Writing tensor blk.37.attn_k.weight                   | size   5120 x   5120  | type F16  | T+ 130
# [337/363] Writing tensor blk.37.attn_v.weight                   | size   5120 x   5120  | type F16  | T+ 130
# [338/363] Writing tensor blk.37.attn_output.weight              | size   5120 x   5120  | type F16  | T+ 130
# [339/363] Writing tensor blk.37.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+ 130
# [340/363] Writing tensor blk.37.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+ 132
# [341/363] Writing tensor blk.37.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+ 132
# [342/363] Writing tensor blk.37.attn_norm.weight                | size   5120           | type F32  | T+ 133
# [343/363] Writing tensor blk.37.ffn_norm.weight                 | size   5120           | type F32  | T+ 133
# [344/363] Writing tensor blk.38.attn_q.weight                   | size   5120 x   5120  | type F16  | T+ 133
# [345/363] Writing tensor blk.38.attn_k.weight                   | size   5120 x   5120  | type F16  | T+ 133
# [346/363] Writing tensor blk.38.attn_v.weight                   | size   5120 x   5120  | type F16  | T+ 133
# [347/363] Writing tensor blk.38.attn_output.weight              | size   5120 x   5120  | type F16  | T+ 133
# [348/363] Writing tensor blk.38.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+ 133
# [349/363] Writing tensor blk.38.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+ 134
# [350/363] Writing tensor blk.38.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+ 135
# [351/363] Writing tensor blk.38.attn_norm.weight                | size   5120           | type F32  | T+ 136
# [352/363] Writing tensor blk.38.ffn_norm.weight                 | size   5120           | type F32  | T+ 136
# [353/363] Writing tensor blk.39.attn_q.weight                   | size   5120 x   5120  | type F16  | T+ 136
# [354/363] Writing tensor blk.39.attn_k.weight                   | size   5120 x   5120  | type F16  | T+ 136
# [355/363] Writing tensor blk.39.attn_v.weight                   | size   5120 x   5120  | type F16  | T+ 137
# [356/363] Writing tensor blk.39.attn_output.weight              | size   5120 x   5120  | type F16  | T+ 137
# [357/363] Writing tensor blk.39.ffn_gate.weight                 | size  13824 x   5120  | type F16  | T+ 137
# [358/363] Writing tensor blk.39.ffn_up.weight                   | size  13824 x   5120  | type F16  | T+ 138
# [359/363] Writing tensor blk.39.ffn_down.weight                 | size   5120 x  13824  | type F16  | T+ 139
# [360/363] Writing tensor blk.39.attn_norm.weight                | size   5120           | type F32  | T+ 141
# [361/363] Writing tensor blk.39.ffn_norm.weight                 | size   5120           | type F32  | T+ 141
# [362/363] Writing tensor output_norm.weight                     | size   5120           | type F32  | T+ 141
# [363/363] Writing tensor output.weight                          | size  55296 x   5120  | type F16  | T+ 142
# Wrote /content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-f16.gguf

# %% [markdown]
# ### 将FP16模型进行量化
#
# 我们进一步将FP16模型转换为量化模型，此处选择的是新版Q6_K方法，其效果非常接近FP16。

# %%
# !cd llama.cpp && ./quantize /content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-f16.gguf /content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-q6_K.bin q6_K
# Out:
# main: build = 1130 (8afe228)
# main: quantizing '/content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-f16.gguf' to '/content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-q6_K.bin' as Q6_K
# llama_model_loader: loaded meta data with 17 key-value pairs and 363 tensors from /content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-f16.gguf (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.we
ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =   135.00 MB ->    55.37 MB | hist:
# [ 342/ 363]              blk.37.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 343/ 363]               blk.37.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 344/ 363]                 blk.38.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 345/ 363]                 blk.38.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 346/ 363]                 blk.38.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 347/ 363]            blk.38.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 348/ 363]               blk.38.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q6_K .. size =   135.00 MB ->    55.37 MB | hist:
# [ 349/ 363]                 blk.38.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q6_K .. size =   135.00 MB ->    55.37 MB | hist:
# [ 350/ 363]               blk.38.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =   135.00 MB ->    55.37 MB | hist:
# [ 351/ 363]              blk.38.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 352/ 363]               blk.38.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 353/ 363]                 blk.39.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 354/ 363]                 blk.39.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 355/ 363]                 blk.39.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 356/ 363]            blk.39.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =    50.00 MB ->    20.51 MB | hist:
# [ 357/ 363]               blk.39.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q6_K .. size =   135.00 MB ->    55.37 MB | hist:
# [ 358/ 363]                 blk.39.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q6_K .. size =   135.00 MB ->    55.37 MB | hist:
# [ 359/ 363]               blk.39.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q6_K .. size =   135.00 MB ->    55.37 MB | hist:
# [ 360/ 363]              blk.39.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 361/ 363]               blk.39.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 362/ 363]                   output_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 363/ 363]                        output.weight - [ 5120, 55296,     1,     1], type =    f16, quantizing to q6_K .. size =   540.00 MB ->   221.48 MB | hist:
# llama_model_quantize_internal: model size  = 25281.58 MB
# llama_model_quantize_internal: quant size  = 10370.33 MB
#
# main: quantize time = 353128.93 ms
# main:    total time = 353128.93 ms

# %% [markdown]
# ### （可选）测试量化模型解码
# 至此已完成了所有转换步骤。
# 我们运行一条命令测试一下是否能够正常加载并进行输出。

# %%
# !cd llama.cpp && ./main -m /content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-q6_K.bin --color -p "[]中的文字是否有旅行意圖：[星期天想去西門町走走，有什麼地方好去?]" -n 256
# Out:
# Log start
# main: build = 1130 (8afe228)
# main: seed  = 1693453497
# llama_model_loader: loaded meta data with 18 key-value pairs and 363 tensors from /content/drive/MyDrive/Llama2_ch/combine_models/ggml-model-q6_K.bin (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q6_K     [  5120, 55296,     1,     1 ]
# llama_model_loader: - tensor    1:              blk.0.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    2:              blk.0.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    4:         blk.0.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    7:            blk.0.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor    8:           blk.0.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor    9:            blk.0.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   10:              blk.1.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   11:              blk.1.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   13:         blk.1.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   16:            blk.1.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   17:           blk.1.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   18:            blk.1.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   19:              blk.2.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   20:              blk.2.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   22:         blk.2.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   23:            blk.2.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   24:              blk.2.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   25:            blk.2.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   26:           blk.2.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   27:            blk.2.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   28:              blk.3.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   29:              blk.3.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   31:         blk.3.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   32:            blk.3.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   33:              blk.3.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   35:           blk.3.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   36:            blk.3.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   37:              blk.4.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   38:              blk.4.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   39:              blk.4.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   40:         blk.4.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   41:            blk.4.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   42:              blk.4.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   43:            blk.4.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   44:           blk.4.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   45:            blk.4.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   46:              blk.5.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   47:              blk.5.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   48:              blk.5.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   49:         blk.5.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   50:            blk.5.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   51:              blk.5.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   52:            blk.5.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   53:           blk.5.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   54:            blk.5.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   55:              blk.6.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   56:              blk.6.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   57:              blk.6.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   58:         blk.6.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   59:            blk.6.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   60:              blk.6.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   61:            blk.6.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   62:           blk.6.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   63:            blk.6.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   64:              blk.7.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   65:              blk.7.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.7.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   67:         blk.7.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   68:            blk.7.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   69:              blk.7.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   70:            blk.7.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   71:           blk.7.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   72:            blk.7.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   73:              blk.8.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   74:              blk.8.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.8.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   76:         blk.8.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   77:            blk.8.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   78:              blk.8.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   79:            blk.8.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   80:           blk.8.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   81:            blk.8.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   82:              blk.9.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   83:              blk.9.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.9.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   85:         blk.9.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   86:            blk.9.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   87:              blk.9.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   88:            blk.9.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   89:           blk.9.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   90:            blk.9.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   91:             blk.10.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   92:             blk.10.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   93:             blk.10.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   94:        blk.10.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   95:           blk.10.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   96:             blk.10.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   97:           blk.10.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   98:          blk.10.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   99:           blk.10.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  100:             blk.11.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  101:             blk.11.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  102:             blk.11.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  103:        blk.11.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  104:           blk
ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  343:             blk.38.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  344:             blk.38.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  345:             blk.38.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  346:        blk.38.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  347:           blk.38.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  348:             blk.38.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  349:           blk.38.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  350:          blk.38.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  351:           blk.38.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  352:             blk.39.attn_q.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  353:             blk.39.attn_k.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  354:             blk.39.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  355:        blk.39.attn_output.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  356:           blk.39.ffn_gate.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  357:             blk.39.ffn_up.weight q6_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  358:           blk.39.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  359:          blk.39.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  360:           blk.39.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  361:               output_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  362:                    output.weight q6_K     [  5120, 55296,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str
# llama_model_loader: - kv   1:                               general.name str
# llama_model_loader: - kv   2:                       llama.context_length u32
# llama_model_loader: - kv   3:                     llama.embedding_length u32
# llama_model_loader: - kv   4:                          llama.block_count u32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32
# llama_model_loader: - kv   7:                 llama.attention.head_count u32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32
# llama_model_loader: - kv  10:                          general.file_type u32
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32
# llama_model_loader: - kv  17:               general.quantization_version u32
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q6_K:  282 tensors
# llm_load_print_meta: format         = GGUF V2 (latest)
# llm_load_print_meta: arch           = llama
# llm_load_print_meta: vocab type     = SPM
# llm_load_print_meta: n_vocab        = 55296
# llm_load_print_meta: n_merges       = 0
# llm_load_print_meta: n_ctx_train    = 4096
# llm_load_print_meta: n_ctx          = 512
# llm_load_print_meta: n_embd         = 5120
# llm_load_print_meta: n_head         = 40
# llm_load_print_meta: n_head_kv      = 40
# llm_load_print_meta: n_layer        = 40
# llm_load_print_meta: n_rot          = 128
# llm_load_print_meta: n_gqa          = 1
# llm_load_print_meta: f_norm_eps     = 1.0e-05
# llm_load_print_meta: f_norm_rms_eps = 1.0e-05
# llm_load_print_meta: n_ff           = 13824
# llm_load_print_meta: freq_base      = 10000.0
# llm_load_print_meta: freq_scale     = 1
# llm_load_print_meta: model type     = 13B
# llm_load_print_meta: model ftype    = mostly Q6_K
# llm_load_print_meta: model size     = 13.25 B
# llm_load_print_meta: general.name   = LLaMA v2
# llm_load_print_meta: BOS token = 1 '<s>'
# llm_load_print_meta: EOS token = 2 '</s>'
# llm_load_print_meta: UNK token = 0 '<unk>'
# llm_load_print_meta: LF token  = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.12 MB
# llm_load_tensors: mem required  = 10370.45 MB (+  400.00 MB per state)
# .................................................................................................
# llama_new_context_with_model: kv self size  =  400.00 MB
# llama_new_context_with_model: compute buffer total size =  119.47 MB
#
# system_info: n_threads = 4 / 8 | AVX = 1 | AVX2 = 1 | AVX512 = 1 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |
# sampling: repeat_last_n = 64, repeat_penalty = 1.100000, presence_penalty = 0.000000, frequency_penalty = 0.000000, top_k = 40, tfs_z = 1.000000, top_p = 0.950000, typical_p = 1.000000, temp = 0.800000, mirostat = 0, mirostat_lr = 0.100000, mirostat_ent = 5.000000
# generate: n_ctx = 512, n_batch = 512, n_predict = 256, n_keep = 0
#
#
#  []中的文字是否有旅行意圖：[星期天想去西門町走走，有什麼地方好去?]
# 答案: 是 [end of text]
#
# llama_print_timings:        load time = 42755.97 ms
# llama_print_timings:      sample time =    12.83 ms /     6 runs   (    2.14 ms per token,   467.73 tokens per second)
# llama_print_timings: prompt eval time =  8837.99 ms /    26 tokens (  339.92 ms per token,     2.94 tokens per second)
# llama_print_timings:        eval time =  2468.17 ms /     5 runs   (  493.63 ms per token,     2.03 tokens per second)
# llama_print_timings:       total time = 11323.94 ms
# Log end
